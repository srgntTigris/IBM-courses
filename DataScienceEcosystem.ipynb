# %% [markdown]
# # Інструменти та екосистема даних

# %% [markdown]
# __Цілі:__
# * Перелік популярнх мов для Data Science
# * Загальновживані бібліотеки науки про Дані
# * Інструменти даних з відкритим кодом
# * арифметичні вирази тощо

# %% [markdown]
# ## У цьому блокноті підсумовані інструменти та екосистема даних

# %% [markdown]
# ### Деякі з популярних мов, які використовують науковці з даних, це:
# 1. Python;
# 2. R;
# 3. SQL.

# %% [markdown]
# ### Деякі з загальновживаних бібліотек, які використовують науковці з даних, включають:
# * NumPy
# * Pandas
# * NumPlotLib
# * SciPy
# * GGplot
# * Caret
# * StringR

# %% [markdown]
# | Інструменти даних |
# | ------ |
# | GitHub |
# | GitLab |
# | Anaconda |
# | Markdown |

# %% [markdown]
# ### Нижче наведено кілька прикладів оцінки арифметичних виразів у Python
# 2+3 = 5
# 3+8=11
# 5+5=10
# $$ sin^2x + cos^2x = 1$$

# %%
#Це простий арифметичний вираз для множення, а потім додавання цілих чисел
(3*4)+5
# Out:
# 17

# %%
#Це перетворить 200 хвилин на години, ділячи на 60

minutes = 200

hours = minutes / 60

print(f"200 хвилин - це {hours} годин")
# Out:
# 200 хвилин - це 3.3333333333333335 годин

# %% [markdown]
# # Автор
# Olena Manich
